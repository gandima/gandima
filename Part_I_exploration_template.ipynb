# %% [markdown]
# # Part I - <font color ="red">PROSPER LOAN </font>
# ## by Geoffrey ANDIMA
#
# ## Introduction
# > <b>This data set contains 113,937 loans with 81 variables on each loan, including loan amount, borrower rate (or interest rate), current loan status, borrower income, and many others.
#
#
#
#
# ## Preliminary Wrangling

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# Let's import the Dataset for the Loan Data

# %%
#This loads the data into a dataframe called loan_df
loans = pd.read_csv('D:/01-DOCS-Personal/Certificates/UDACITY/Data Analyst/Data Visualization in Data Analysis/Project Loan Data/prosperLoanData.csv')

# %%
#Let's now examine the dataset
loans.shape
# Out:
# (113937, 81)

# %%
loans.sample(5)
# Out:
#                     ListingKey  ListingNumber            ListingCreationDate  \
# 16858  54FF3420881763585912E9B         337833  2008-05-23 08:24:43.037000000
# 62625  D31C3590470906428C34DF4         921984  2013-09-25 03:09:45.547000000
# 80956  4C4634206675292780E7C79         333667  2008-05-15 22:20:19.820000000
# 58684  4BBC35975373012617E399F        1069135  2013-12-31 08:55:59.883000000
# 46302  DAAF3593113156393E1164D        1011756  2013-10-27 23:02:49.117000000
#
#       CreditGrade  Term LoanStatus           ClosedDate  BorrowerAPR  \
# 16858           C    36  Completed  2011-03-25 00:00:00      0.24771
# 62625         NaN    36    Current                  NaN      0.23540
# 80956           C    36  Completed  2009-08-04 00:00:00      0.12562
# 58684         NaN    36    Current                  NaN      0.13799
# 46302         NaN    60    Current                  NaN      0.14760
#
#        BorrowerRate  LenderYield  ...  LP_ServiceFees  LP_CollectionFees  \
# ...

# %%
#lets have alook at quick stats from the dataset loan_df
loans.describe()
# Out:
#        ListingNumber           Term    BorrowerAPR   BorrowerRate  \
# count   1.139370e+05  113937.000000  113912.000000  113937.000000
# mean    6.278857e+05      40.830248       0.218828       0.192764
# std     3.280762e+05      10.436212       0.080364       0.074818
# min     4.000000e+00      12.000000       0.006530       0.000000
# 25%     4.009190e+05      36.000000       0.156290       0.134000
# 50%     6.005540e+05      36.000000       0.209760       0.184000
# 75%     8.926340e+05      36.000000       0.283810       0.250000
# max     1.255725e+06      60.000000       0.512290       0.497500
#
#          LenderYield  EstimatedEffectiveYield  EstimatedLoss  EstimatedReturn  \
# count  113937.000000             84853.000000   84853.000000     84853.000000
# mean        0.182701                 0.168661       0.080306         0.096068
# std         0.074516                 0.068467       0.046764         0.030403
# ...

# %%
#quick info for types and nulls
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113937 entries, 0 to 113936
# Data columns (total 81 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   ListingKey                           113937 non-null  object
#  1   ListingNumber                        113937 non-null  int64
#  2   ListingCreationDate                  113937 non-null  object
#  3   CreditGrade                          28953 non-null   object
#  4   Term                                 113937 non-null  int64
#  5   LoanStatus                           113937 non-null  object
#  6   ClosedDate                           55089 non-null   object
#  7   BorrowerAPR                          113912 non-null  float64
#  8   BorrowerRate                         113937 non-null  float64
#  9   LenderYield                          113937 non-null  float64
# ...

# %%
#let check and ascertain null values on each of the 81 columns.

loans.isnull().sum()
# Out:
# ListingKey                         0
# ListingNumber                      0
# ListingCreationDate                0
# CreditGrade                    84984
# Term                               0
#                                ...
# PercentFunded                      0
# Recommendations                    0
# InvestmentFromFriendsCount         0
# InvestmentFromFriendsAmount        0
# Investors                          0
# Length: 81, dtype: int64

# %%
#Let's now keep only the columns we are interested in for our analysis
wanted_columns = ['LoanStatus','Term','Occupation','EmploymentStatus','BorrowerState','BorrowerRate','ListingCategory (numeric)','LoanOriginalAmount','ProsperScore','EstimatedLoss','IsBorrowerHomeowner','CreditScoreRangeUpper','CreditScoreRangeLower','MonthlyLoanPayment','LoanOriginationDate','StatedMonthlyIncome','IncomeRange']
loan_df = loans[wanted_columns]

# %%
loan_df.head()
# Out:
#   LoanStatus  Term     Occupation EmploymentStatus BorrowerState  \
# 0  Completed    36          Other    Self-employed            CO
# 1    Current    36   Professional         Employed            CO
# 2  Completed    36          Other    Not available            GA
# 3    Current    36  Skilled Labor         Employed            GA
# 4    Current    36      Executive         Employed            MN
#
#    BorrowerRate  ListingCategory (numeric)  LoanOriginalAmount  ProsperScore  \
# 0        0.1580                          0                9425           NaN
# 1        0.0920                          2               10000           7.0
# 2        0.2750                          0                3001           NaN
# 3        0.0974                         16               10000           9.0
# 4        0.2085                          2               15000           4.0
#
#    EstimatedLoss  IsBorrowerHomeowner  CreditScoreRangeUpper  \
# ...

# %% [markdown]
# <b> Let's make a copy of the df for our further cleaning.

# %%
loans_df_clean = loan_df.copy()

# %% [markdown]
# From the Prosper Loan Data-Variable definitions, we were told that;
# The category of the listing that the borrower selected when posting their listing: 0 - Not Available, 1 - Debt Consolidation, 2 - Home Improvement, 3 - Business, 4 - Personal Loan, 5 - Student Use, 6 - Auto, 7- Other, 8 - Baby&Adoption, 9 - Boat, 10 - Cosmetic Procedure, 11 - Engagement Ring, 12 - Green Loans, 13 - Household Expenses, 14 - Large Purchases, 15 - Medical/Dental, 16 - Motorcycle, 17 - RV, 18 - Taxes, 19 - Vacation, 20 - Wedding Loans
#
# <b> Let's have a fucntion to replace the numeric values with the variables definition.

# %%
    
    #This function replaces the numeric values ListingCategory (numeric) with the respective listing variables privided in the 
    #Prosper Loan Data-Variable definitions
    
    def replace_numeric_cat(numeric):    
   list_dict = {0:'Not Available', 1:'Debt Consolidation',2:'Home Improvement',
                 3:'Business',4:'Personal Loan',5:'Student Use',6:'Auto',7:'Other',
                 8:'Baby&Adoption',9:'Boat',10:'Cosmetic Procedure',
                 11:'Engagement Ring',12:'Green Loans',13:'Household Expenses',
                 14:'Large Purchases',15:'Medical/Dental',16:'Motorcycle',17:'RV',
                 18:'Taxes', 19:'Vacation', 20:'Wedding Loans'}
       return list_dict[numeric]

# %%
#This function replaces the numeric values ListingCategory (numeric) and puts them in a new column called ListingCategory
loans_df_clean['ListingCategory'] = loans_df_clean['ListingCategory (numeric)'].apply(replace_numeric_cat)

# %%
#This code checks to see if the column with string values has been added to the data frame.
loans_df_clean.head(3)
# Out:
#   LoanStatus  Term    Occupation EmploymentStatus BorrowerState  BorrowerRate  \
# 0  Completed    36         Other    Self-employed            CO         0.158
# 1    Current    36  Professional         Employed            CO         0.092
# 2  Completed    36         Other    Not available            GA         0.275
#
#    ListingCategory (numeric)  LoanOriginalAmount  ProsperScore  EstimatedLoss  \
# 0                          0                9425           NaN            NaN
# 1                          2               10000           7.0         0.0249
# 2                          0                3001           NaN            NaN
#
#    IsBorrowerHomeowner  CreditScoreRangeUpper  CreditScoreRangeLower  \
# 0                 True                  659.0                  640.0
# 1                False                  699.0                  680.0
# 2                False                  499.0                  480.0
#
# ...

# %%
#Now we shalf we go ahead and drop the column with numeric listing since from above, we can see that it has been replaced.

loans_df_clean.drop(['ListingCategory (numeric)'], axis=1, inplace=True)

# %% [markdown]
# <b> Let's now change the value of True to Yes, False to NO.

# %%
loans_df_clean['IsBorrowerHomeowner'] = loans_df_clean['IsBorrowerHomeowner'].map({True:'YES' ,False:'NO'})

# %% [markdown]
# <b> We shall then change the employment status to be uniform. Self employed, Full-time, Employed, Part-time will all be classified as Employed Status.

# %%
loans_df_clean['EmploymentStatus'] = loans_df_clean['EmploymentStatus'].map({'Self-employed':'Employed' ,'Full-time':'Employed','Part-time':'Employed','Retired':'Retired','Not available':'Not available','Other':'Other','Not employed':'Not employed','Employed':'Employed'})

# %%
#This code checks to see if the numeric column has been dropped.
loans_df_clean.head(13)
# Out:
#               LoanStatus  Term       Occupation EmploymentStatus  \
# 0              Completed    36            Other         Employed
# 1                Current    36     Professional         Employed
# 2              Completed    36            Other    Not available
# 3                Current    36    Skilled Labor         Employed
# 4                Current    36        Executive         Employed
# 5                Current    60     Professional         Employed
# 6                Current    36   Sales - Retail         Employed
# 7                Current    36          Laborer         Employed
# 8                Current    36     Food Service         Employed
# 9                Current    36     Food Service         Employed
# 10               Current    60          Fireman         Employed
# 11             Completed    36  Waiter/Waitress         Employed
# 12  Past Due (1-15 days)    36   Sales - Retail         Employed
#
# ...

# %% [markdown]
# <font color= 'red'><b>We now have our clean data to start the analysis.</font>

# %% [markdown]
# ### What is the structure of your dataset?
#
# > The Dataset contains <b><font color = 'red'>113937</font></b> loan entries (rows) and <b><font color = 'red'>81</font></b> attributes [columns].
#
# ### What is/are the main feature(s) of interest in your dataset?
# - <b>LoanStatus:</b> The current status of the loan.
# - <b>Term:</b> The length of the Loan in terms of months.
# - <b>EmploymentStatus:</b> Employment status, when listing was created
# - <b>BorrowerState:</b> The state in which the borrower comes from/resides.
# - <b>BorrowerRate:</b> Interest Rate on the loan taken by the borrower.
# - <b>ListingCategory (numeric):</b> The category of the loan.
# - <b>ProsperScore:</b> Custom Risk Score
# - <b>EstimatedLoss:</b> Estimated Principal loss.
# - <b>IsBorrowerHomeowner:</b> Does the borrower own a home ?
# - <b>CreditScoreRange:</b> The upper and lower values of the Credit Score Range.
# - <b>MonthlyLoanPayment:</b> The monthly installment that is to be paid.
# - <b>LoanOriginationDate:</b> The date at which the loan was issued.
# - <b>StatedMonthlyIncome:</b> The monthly income of the borrower stated at the time the loan was issued.
# - <b>IncomeRange:</b> IncomeRange of borrowers.
#
#
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > <b>Prosper Score will help determine worthness and abilty of borrowers to pay back., Home ownership will help understand if Home ownership status favours getting of the loan.

# %% [markdown]
# ## Univariate Exploration
#
# > In this section, we investigate distributions of individual variables.

# %% [markdown]
# # QN: What are the top 10 states with the least number of borrowers?

# %%
#these codes are used to get the top 10 states and there value counts.
least_borrower_states = loans_df_clean['BorrowerState'].value_counts()[-10:].index.tolist()
least_borrower_totals = loans_df_clean['BorrowerState'].value_counts()[-10:].values.tolist()

# %%
sb.set(style='dark',)
plt.figure(figsize=(15,5))

ax = sb.barplot(x=least_borrower_totals, y=least_borrower_states, color = 'green')
plt.xlabel('Total number of borrowers',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.ylabel('States',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.title('What are the top 10 states with the least number of borrowers?' , size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold")

#lets now display the value lables using containers as shwoed in the class.
for i in ax.containers:
    ax.bar_label(i,)

# %% [markdown]
# <font color ="blue"><b>INSIGHT:</font> <b> From the above graph, It can be observed that the state with the least number of borrowers is <font color ="red">North DAKOTA</font> with 52 borrowers, followed by Maine with 101, Wyoming with 150,and Iowa with 186

# %% [markdown]
# # QN: What are the top 10 states with the most  number of borrowers?

# %%
most_borrower_states = loans_df_clean['BorrowerState'].value_counts()[:10].index.tolist()
most_borrower_totals = loans_df_clean['BorrowerState'].value_counts()[:10].values.tolist()

# %%
sb.set(style='dark',)
plt.figure(figsize=(15,5))

ax=sb.barplot(x=most_borrower_totals, y=most_borrower_states, color = 'brown')
plt.xlabel('Total number of borrowers',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.ylabel('States',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.title('What are the top 10 states with the most number of borrowers?' , size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold")


#lets now display the value lables using containers as shwoed in the class.
for i in ax.containers:
    ax.bar_label(i,)

# %% [markdown]
# <font color ="blue"><b>INSIGHT:</font> <b> From the above graph, It can be observed that the state with the least number of borrowers is <font color ="red">CALIFORNIA</font> with 14,717, followed by TEXAS with 6,842, NEW YORK with 6,729,and FLORIDA with 6,720

# %% [markdown]
# # QN: What is the total number of borrowers who own homes?

# %%
sb.set(style='dark',)
fig = plt.figure(figsize=(10,5))

ax=sb.countplot(x='IsBorrowerHomeowner', data=loans_df_clean, color ="cyan")
plt.title('What is the total number of borrowers who own homes?',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold")
plt.ylabel('Total number of borrowers',size=10,fontname="DejaVu Sans", fontweight="bold")

#Lets display the totals on the top of the graphs.
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# <font color ="blue"><b>INSIGHT:</font> <b> <b> From the above graph, It can be observed that the number of borrowers who own homes is higher that those who don't by a small difference. <font color ="red">57,478</font> borrowers own homes as compared to <font color ="red">56,459</font> who don't.

# %% [markdown]
# From the employment status, Self-employed, Employed, Full-time and part-time is part a type of employment status

# %%
sb.set(style='dark',)
fig = plt.figure(figsize=(15,6))
ax=sb.countplot(y='EmploymentStatus', data= loans_df_clean, color = 'purple')
plt.ylabel('Employment status', size=10,fontname="DejaVu Sans", fontweight="bold")
plt.xlabel('Total number of Borrowers',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.title('What is the total number of borrowers by employment status?',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold")

for i in ax.containers:
    ax.bar_label(i,)
    plt.show()

# %% [markdown]
# <font color ="blue"><b>INSIGHT:</font> <b> From the above graph, it can be observed that most borrowers are employed. A total of <font color ="red">100,899</font> borrowers are employed, <font color ="red">835</font> borrowers not employed, <font color ="red">795</font> retired, <font color ="red">5,347</font> have employment status listed as not available and <font color ="red">3,806</font> listed as others.

# %% [markdown]
# # QN:What is the total number of borrowers by Prosper score?

# %% [markdown]
# From the variable definition, it was noted that prosper score is a custom risk score built using historical Prosper data.
# The score ranges from 1-10, with 10 being the best, or lowest risk score.  Applicable for loans

# %%
#let's filter and have prosper score less than or equall to 10 since we saw that some values have score of values above 10.

prosper_clean = loans_df_clean.loc[loans_df_clean['ProsperScore'] <= 10]

# %%
sb.set(style='dark',)
fig = plt.figure(figsize=(15,5))
ax=sb.countplot(x='ProsperScore', data=prosper_clean,color='Orange')
plt.title('Whats is the total number of borrowers by Prosper Score',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold")
plt.xlabel('Prosper Score',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.ylabel('Total number of borrowers',size=10,fontname="DejaVu Sans", fontweight="bold")
for i in ax.containers:
    ax.bar_label(i,)
    plt.show()

# %% [markdown]
# <font color ="blue"><b>INSIGHT:</font> <b> From the above, it can be observed that borrowers with the lowest risk score (best) are few. Most borrowers have a high risk score ranging from <font color ="red">4</font> to <font color ="red">8</font>.

# %% [markdown]
# # QN What are the total borrowers by Loan Status?

# %%
sb.set(style='dark',)   
fig = plt.figure(figsize=(15,5))
ax=sb.countplot(y='LoanStatus', data= loans_df_clean, order = loans_df_clean['LoanStatus'].value_counts().index)
plt.ylabel('Loan Status', size=10,fontname="DejaVu Sans", fontweight="bold")
plt.xlabel('Total number of Borrowers',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.title('What are the total borrowers by Loan status?',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold")

for i in ax.containers:
    ax.bar_label(i,)
    plt.show()

# %% [markdown]
# <font color ="blue"><b>INSIGHT:</font> <b> From the above graph, it can be observed that most of the loans are current, with <font color ="red">56,576</font> borrowers currently servicing their loans, <font color ="red">38074</font> borrowers completed paying. It can also be noted that <font color ="red">16</font> are past due and <font color ="red">5</font> were cancelled.

# %% [markdown]
# # QN: What is the total distribution of Loans by Term [time taken]?

# %%
sb.set(style='dark',)
fig = plt.figure(figsize=(15,4))
ax=sb.countplot(y='Term', data= loans_df_clean, color = "red", order = loans_df_clean['Term'].value_counts().index)
plt.ylabel('Term to repay loan', size=10,fontname="DejaVu Sans", fontweight="bold")
plt.xlabel('Total number of borrowers',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.title('What are the total borrowers by Loan Term?',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold")

for i in ax.containers:
    ax.bar_label(i,)
    plt.show()

# %% [markdown]
# <font color ="blue"><b>INSIGHT:</font> <b> From the above graph, it can be observed that most loans are for <font color ="red">36</font> with the least being for <font color ="red">12</font>

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > YES: Transformed the home False and True values to have a better representation
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# >
# changed to employment status of full-time, part-time, self-employed to all be represented as
# employed as they're all types of employment.

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, we investigate relationships between pairs of variables,

# %% [markdown]
# # QN: What is the correlation between prosper score and credit score?

# %%
num_var_1 = ['ProsperScore','CreditScoreRangeUpper']
plt.figure(figsize = [10, 5])
sb.heatmap(loans_df_clean[num_var_1].corr(), annot = True, fmt = '.3f', cmap = 'vlag_r', center = 0)
plt.title('What is the correlation between prosper score and credit score?',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold") 
plt.show()

# %% [markdown]
# <font color ="blue"><b>Correlation Inisght:</font> <b>There is a strong positive relationships between Prosper Score and Credit Score. This is because when one has a high credit score rating, this implies that his prosper score will be the best [least], as trustworthy of the borrower to pay back the loan is very high.

# %% [markdown]
# # QN: What is the correlation between prosper score and term?

# %%
num_var_2 = ['ProsperScore','Term']


plt.figure(figsize = [10, 5])
sb.heatmap(loans_df_clean[num_var_2].corr(), annot = True, fmt = '.3f',cmap = 'vlag_r', center = 0)
plt.title('What is the correlation between prosper score and term?',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold") 
plt.show()

# %% [markdown]
# <font color ="blue"><b>Correlation Inisght:</font> <b>There is no positive/strong relationship between Prosper Score and term. This is because even those who take small term loans can default.

# %% [markdown]
# We can go ahead and check the relationship between the pairs using the pairgrid.

# %%
num_vars_3 = ['BorrowerRate', 'StatedMonthlyIncome']

plt.figure(figsize = [10, 5])
sb.heatmap(loans_df_clean[num_vars_3].corr(), annot = True, fmt = '.3f',cmap = 'vlag_r', center = 0)
plt.title('What is the correlation between BorrowerRate and Stated Monthly Income?',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold") 
plt.show()

# %% [markdown]
# <font color ="blue"><b>Correlation Inisght:</font> <b>There is no positive/strong relationship between Borrower Rate and Stated Monthly Income. This is because loans can have a flat rate for all borrowers.

# %% [markdown]
# # QN: What's the correlation between stated income and prosper scores ?

# %%
fig = plt.figure(figsize=(15,5))
sb.pointplot(y='StatedMonthlyIncome', x='ProsperScore', data=prosper_clean,marker='o',scale = 1.5)
plt.title('What is the correlation between stated monthly income and prosper scores?',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold")
plt.xlabel('Prosper Score',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.ylabel('Stated Monthly Income',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.show()

# %% [markdown]
# <font color ="blue"><b>Correlation Inisght:</font> <b>From the above, It can be observed that there is a strong positive correlation between stated monthly income and Prosper score. The Higher the stated monthly income, the higher the prosper score. This is because borrowers who earn higher salaries are trusted to be more likely yo payback.

# %% [markdown]
# # QN: What is the correlation between home ownership status and prosper score?

# %%
fig = plt.figure(figsize=(12,6))
sb.countplot(hue='IsBorrowerHomeowner', x='ProsperScore', data=prosper_clean)
plt.title('Relationship Between Prosper Score & Home Ownership',size=12, fontname="DejaVu Sans", color ="brown", fontweight="bold")
plt.ylabel('Total number of borrowers',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.xlabel('Prosper Score',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.show()

# %% [markdown]
# <font color ="blue"><b>Correlation Inisght:</font> <b>It can be noted that most borrowers with the best prosper score [8 to 10] own homes..while those with relatively high scores don't own homes [2 to 3].

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > It can be noted that most borrowers with the best prosper score [8 to 10] own homes..while those with relatively high scores don't own homes [2 to 3].
#
# >It can be observed that there is a strong positive correlation between stated monthly income and Prosper score. The Higher the stated monthly income, the higher the prosper score. This is because borrowers who earn higher salaries are trusted to be more likely yo payback.
#
# >There is no positive/strong relationship between Borrower Rate and Stated Monthly Income. This is because loans can have a flat rate for all borrowers.
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# >There is no positive/strong relationship between Borrower Rate and Stated Monthly Income. This is because loans can have a flat rate for all borrowers.

# %% [markdown]
# ## Multivariate Exploration

# %% [markdown]
# # QN: What is the relationship between prosper score, borrower rate and estimated loss?

# %%
fig = plt.figure(figsize=(10,5))
sb.scatterplot(x='ProsperScore', y='BorrowerRate',
                hue='EstimatedLoss',y_jitter=0.5, data=loans_df_clean, palette='OrRd')
plt.title('What is the relationship between Prosper score, borrower rate and estimated loss?')
plt.xlabel('Proseper Score',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.ylabel('Browwer Rate',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.show()

# %% [markdown]
# <font color ="blue"><b>Correlation Inisght:</font> <b> From the above, it can be ovserved that there is a strong relationship between prosper score, borrower rate and estimated loss. high prosper scores are associated with high borrower rates and estimated loss. As the prosper score lowers [from 8 to 10], the borrower rates and estimated rates also lower.

# %% [markdown]
# # QN: What is the relationship between prosper score, Loan amount and monthly loan payments ?

# %%
fig = plt.figure(figsize=(10,5))
sb.scatterplot(x='LoanOriginalAmount', y='MonthlyLoanPayment',
                hue='ProsperScore',y_jitter=0.5, data=loans_df_clean, palette='OrRd')
plt.title('What is the relationship between prosper score, Loan amount and monthly loan payments ?')
plt.xlabel('Loan Original Amount',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.ylabel('Monthly Loan Payment',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.show()

# %% [markdown]
# <font color ="blue"><b>Correlation Inisght:</font> <b>
# <b>From the above graph, it can be observed that a relationship exists between monthly loan payments and the loan original amount. A Higher Loan Amount taken by borrowers leads to Higher monthly loan payments. It can also be observed that the least/best prosper scores [8 to 10] get higher loans as compared to mostly those with higher prosper scores [2 to 6]

# %% [markdown]
# # QN: What is the relationship between prosper score, home ownership and loan amount?

# %%
fig = plt.figure(figsize=(10,5))
sb.scatterplot(x='LoanOriginalAmount', y='ProsperScore',
                hue='IsBorrowerHomeowner',y_jitter=0.5, data=loans_df_clean, palette='OrRd')
plt.title('What is the relationship between prosper score, home ownership and loan amount?')
plt.xlabel('Loan Original Amount',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.ylabel('Credit Score Range',size=10,fontname="DejaVu Sans", fontweight="bold")
plt.show()

# %% [markdown]
# <font color ="blue"><b>Correlation Inisght:</font> <b>
# <b>From the above graph, a relationship can be observed among the three. Borrowers who are home owners and have the least prosper score tend to take bigger loans. It can also be observed that most of the small loans ranging from 5000 to 15000 are mostly taken by borrowers who don't own homes, it can also be seen that borrower who own and those who don't, end up getting lower loans as long as their propsper score is high. [2 to 6 and 5000 to 15000] range.

# %% [markdown]
# <font color ="red">The above can also represneted futher clearly using a map

# %%
fig = plt.figure(figsize=(20,5))

a=sb.FacetGrid(data = loans_df_clean, col = 'IsBorrowerHomeowner', col_wrap = 4, height = 5)
a.map(plt.scatter, 'LoanOriginalAmount', 'ProsperScore', alpha = 0.1,)
plt.xlabel('LoanOriginalAmoun')
plt.ylabel('ProsperScore')

plt.show()

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > There is a strong positive relationships between Prosper Score and Credit Score. This is because when one has a high credit score rating, this implies that his prosper score will be the best [least], as trustworthy of the borrower to pay back the loan is very high.
#
# > It can be observed that a relationship exists between monthly loan payments and the loan original amount. A Higher Loan Amount taken by borrowers leads to Higher monthly loan payments. It can also be observed that the least/best prosper scores [8 to 10] get higher loans as compared to mostly those with higher prosper scores [2 to 6]
#
# ### Were there any interesting or surprising interactions between features?
#
# > Having no relationship between borrower rate and monthly salary was surprising

# %% [markdown]
# ## Conclusions
# > <b>There is a strong positive relationships between Prosper Score and Credit Score. This is because when one has a high credit score rating, this implies that his prosper score will be the best [least], as trustworthy of the borrower to pay back the loan is very high.
#
# > <b> It can be observed that the state with the least number of borrowers is North DAKOTA with 52 borrowers, followed by Maine with 101, Wyoming with 150,and Iowa with 186
#
#
# > <b> It can be observed that the number of borrowers who own homes is higher that those who don't by a small difference. 57,478 borrowers own homes as compared to 56,459 who don't.
#
#
# > <b> It can be observed that the state with the least number of borrowers is CALIFORNIA with 14,717, followed by TEXAS with 6,842, NEW YORK with 6,729,and FLORIDA with 6,720
#
# > <b> It can be observed that most borrowers are employed. A total of 100,899 borrowers are employed, 835 borrowers not employed, 795 retired, 5,347 have employment status listed as not available and 3,806 listed as others.
#
# > <b> It can be observed that borrowers with the lowest risk score (best) are few. Most borrowers have a high risk score ranging from 4 to 8.
#
# > <b> It can be observed that most of the loans are current, with 56,576 borrowers currently servicing their loans, 38074 borrowers completed paying. It can also be noted that 16 are past due and 5 were cancelled.
#
# > <b> There is a strong positive relationships between Prosper Score and Credit Score. This is because when one has a high credit score rating, this implies that his prosper score will be the best [least], as trustworthy of the borrower to pay back the loan is very high.
#
# > <b> There is no positive/strong relationship between Prosper Score and term. This is because even those who take small term loans can default.
#
# > <b> There is no positive/strong relationship between Borrower Rate and Stated Monthly Income. This is because loans can have a flat rate for all borrowers.
#
# > <b> It can be observed that there is a strong positive correlation between stated monthly income and Prosper score. The Higher the stated monthly income, the higher the prosper score. This is because borrowers who earn higher salaries are trusted to be more likely yo payback.
#
# > <b> It can be noted that most borrowers with the best prosper score [8 to 10] own homes..while those with relatively high scores don't own homes [2 to 3].
#
# > <b> It can be ovserved that there is a strong relationship between prosper score, borrower rate and estimated loss. high prosper scores are associated with high borrower rates and estimated loss. As the prosper score lowers [from 8 to 10], the borrower rates and estimated rates also lower.
#
# > <b> It can be observed that a relationship exists between monthly loan payments and the loan original amount. A Higher Loan Amount taken by borrowers leads to Higher monthly loan payments. It can also be observed that the least/best prosper scores [8 to 10] get higher loans as compared to mostly those with higher prosper scores [2 to 6]
#
# > <b> A relationship can be observed among the three. Borrowers who are home owners and have the least prosper score tend to take bigger loans. It can also be observed that most of the small loans ranging from 5000 to 15000 are mostly taken by borrowers who don't own homes, it can also be seen that borrower who own and those who don't, end up getting lower loans as long as their propsper score is high. [2 to 6 and 5000 to 15000] range.
